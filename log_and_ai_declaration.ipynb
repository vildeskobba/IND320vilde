# %% [markdown]
# # Log
# Must include a 300-500-word log describing the compulsory work (including both Jupyter Notebook and Streamlit experience).

# %% [markdown]
# # AI usage
# Must include a brief description of AI usage.
# I spent the summer cleaning up some vibe coded mess of an app, so I prefer to keep AI-use to a minimum.
# I tend to use an LLM to ask qustions and generate simple short code snippets, but I have to admit I'm not a fan of using an agent inside the IDE at my stage.
# I think that as a student I need more time to write code the "old fashioned" way, in order to understand all aspects of what I am building.
